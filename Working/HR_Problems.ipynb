# %% [raw]
# Contents
# 1.  Python Division
# 2.  Strings
# 2.1 Lists
# 3.  Math
# 4.  Exceptions
# 5.  Built In
# 6.  Python Functionals - Lambda, Map, Reduce
# 7.  Regex and Parsing
#
# 8.  Self Study - Regex and Parsing
# 9.  Self Study - Strings
# 10. Self Study - Map and Reduce

# %%
# 1 Python Division
a = int(input())
b = int(input())
print("{0}\n{1}".format(a//b, a/b))

# using * in arguments means a list will be converted in to an array.
# Thus a list of 3 elements will be converted into an array and passed as 3 arguments.
print(*range(1, int(input())+1), sep='')

# %%
# 2. STRINGS

# 1. swap case
def swap_case(s):
    s = s.swapcase()
    return s
# 1. swap case
def swap_case1():
    print (''.join([i.lower() if i.isupper() else i.upper() for i in input()]))
# 2. Split and Join
def split_and_join(line):
    line = line.split(' ')
    line = "-".join(line)
    return line
# 3. Print names
def print_full_name(a, b):
    print("Hello "+a+" "+b+"! You just delved into python.")
    return
# 3. Print names
def print_full_name1():
    print ("Hello {0} {1}! You just delved into python.".format(input(), input()))
#  4. Mutate a String 
def mutate_string(string, position, character):
    li = list(string)
    j = list(character)
    li = li[:position]+j+li[position+1:]
    l = ''.join(li)
    return l
# 5. Find occurences of a string 
def count_substring(string, sub_string):
    n = len(sub_string)
    results = 0
    for q in range(len(string)):
        if string[q:q+n] == sub_string:
            results += 1
    return results
# 5. Find occurences of a string 
def findocc():
    string, substring = (input().strip(), input().strip())
    print(sum([ 1 for i in range(len(string)-len(substring)+1) if string[i:i+len(substring)] == substring]))
    #  6. String Validators
    str = input()
    print (any(c.isalnum()  for c in str))
    print (any(c.isalpha() for c in str))
    print (any(c.isdigit() for c in str))
    print (any(c.islower() for c in str))
    print (any(c.isupper() for c in str))
# 7. Text wrap
def wrap(string, max_width):
    return textwrap.fill(string,max_width)
# 7. Text wrap
# Without using textwrap
def wrap1():
    a, b = input(), int(input())
    for i in range(0,len(a),b):
        print(a[i:i+b])
    #  8. String Formatting
    #  https://pyformat.info/
    def print_formatted(number):
        # your code goes here
        for i in range(1,number+1):
            k = len(str(bin(number)))-1
            a = (str(oct(i))[2:]).rjust(k,' ')
            b = (str(hex(i))[2:]).rjust(k,' ')
            c = (str(bin(i))[2:]).rjust(k,' ')
            j = str(i).rjust(k-1,' ')
            print(j+a+b.upper()+c)
#  8. String Formatting        
def strformat():
    n = int(input())
    width = len("{0:b}".format(n))
    for i in xrange(1,n+1):
        print("{0:{width}d} {0:{width}o} {0:{width}X} {0:{width}b}".format(i, width=width))
# 9. Alphabet rangoli
def print_rangoli(size):
    alp="abcdefghijklmnopqrstuvwxyz"
    s1=s2=size
    sub=alp[:size]
    b='-'.join(reversed(sub))
    sub='-'.join(sub)
    j=1
    k=len(b)
    for i in range(size,0,-1):
        print (('-'*((i*2)-2))+b[0:j]+sub[k:len(b)]+('-'*((i*2)-2)))
        j=j+2
        k=k-2
    x=len(b)-2
    y=1
    for i in range(1,size):
        print(('-'*(2*i))+b[0:x]+sub[(y+2):len(sub)]+('-'*(2*i)))
        x=x-2
        y+=2
# 9. Alphabet rangoli        
def rangoli():
    import string
    alpha = string.ascii_lowercase
    n = int(input())
    L = []
    for i in range(n):
        s = "-".join(alpha[i:n])
        L.append((s[::-1]+s[1:]).center(4*n-3, "-"))
    print('\n'.join(L[:0:-1]+L))
# 10. Capitalize
def capitalize(string):
        return ' '.join(map(str.capitalize, string.split(' ')))

# %%
# 2.1 Lists
# Question: Nested Lists in Python
def stulist():
    students = []
    s = []
    for _ in range(int(input())):
        name = input()
        score = float(input())
        students.append([name,score])
    stu = sorted(students,key = lambda x:x[1])
    _score = [i[1] for i in students]
    s_score = list(set(_score))
    s_score.sort()
    [s.append(i) for i in stu if i[1] == s_score[1]]
    ss = sorted(s,key = lambda x:x[0])
    for i in ss:
        print(i[0],sep=',')

    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    d = (sum(student_marks[name])/3)
    print("%.2f" % d)
    # query_name = input()

def stu(s):
    dit = {}
    di = {}
    gi = {}
    r = 0
    vow = ['A','E','I','O','U']
    for i in range(0,len(s)):
        if s[i] not in vow:
            r = i+1
            break
    for i in range(0,len(s)):
        if s[i] not in vow:
            if s[i] in dit:
                dit[s[i]] += 1
            else:
                dit[s[i]] = 1
    print (r,len(s), dit)
    for i in range(r,len(s)):
        if(i!=r):
            for key,value in dit.items():
                if key in gi:
                    n = key + s[i]
                    sub_len = len(n)
                    results = 0
                    for q in range(len(s)):
                        if s[q:q+sub_len] == n:
                            results += 1
                    for m in range(0,results):
                        if n in di:
                            di[n] += 1
                        else:
                            di[n] = 1
            gi = di
            print(di, sep = '\n')
            dit.update(di) 
            di = {}
        else:
            for key,value in dit.items():
                n = key + s[i]
                sub_len = len(n)
                results = 0
                for q in range(len(s)):
                    if s[q:q+sub_len] == n:
                        results += 1
                for m in range(0,results):
                    if n in di:
                        di[n] += 1
                    else:
                        di[n] = 1
            gi = di
            print(di, sep = '\n')
            dit.update(di) 
            di = {}
    #     print ("count", len(dit),dit, '\n')
    total = 0
    for key,value in dit.items():
        total = total + dit[key]
    print ("STUART ",total)

def kev(s):
    dit = {}
    di = {}
    gi = {}
    r = 0
    vow = ['A','E','I','O','U']
    for i in range(0,len(s)):
        if s[i] in vow:
            r = i+1
            break
    for i in range(0,len(s)):
        if s[i] in vow:
            if s[i] in dit:
                dit[s[i]] += 1
            else:
                dit[s[i]] = 1
    for i in range(r,len(s)):
        if(i!=r):
            for key,value in dit.items():
                if key in gi:
                    n = key + s[i]
                    sub_len = len(n)
                    results = 0
                    for q in range(len(s)):
                        if s[q:q+sub_len] == n:
                            results += 1
                    for m in range(0,results):
                        if n in di:
                            di[n] += 1
                        else:
                            di[n] = 1
            gi = di
            print(di, sep = '\n')
            dit.update(di) 
            di = {}
        else:
            for key,value in dit.items():
                n = key + s[i]
                sub_len = len(n)
                results = 0
                for q in range(len(s)):
                    if s[q:q+sub_len] == n:
                        results += 1
                for m in range(0,results):
                    if n in di:
                        di[n] += 1
                    else:
                        di[n] = 1
            gi = di
            print(di, sep = '\n')
            dit.update(di) 
            di = {}
    ktotal = 0
    for key,value in dit.items():
        ktotal = ktotal + dit[key]
    print(ktotal)
    if(total<ktotal):
        print("KEVIN ",ktotal)
    else:
        print("STUART ",total)
        
inp = "BLUEBERRY"
stu(inp)
kev(inp)

# %%
#  MATH


# 1. itertools.product
def prod():
    from itertools import product
    A=list(map(int,input().split()))
    B=list(map(int,input().split()))
    print(*product(A,B))
# 1. itertools.product
def prod1():
    from itertools import product
    print(*product(map(int,input().split()),map(int,input().split())))

# 2. itertools.permutations()
def permute():
    from itertools import permutations
    inp = input().split()
    j = list(permutations(inp[0],int(inp[1])))
    k = [''.join(i) for i in j]
    k.sort()
    print (*k, sep = '\n')
# 2. itertools.permutations()
def permute1():
    from itertools import permutations
    s,n = input().split()
    print(*[''.join(i) for i in permutations(sorted(s),int(n))],sep='\n')
# 3. itertools.combinations()
def comb():
    from itertools import combinations
    line= input().split()
    for k in range(1,int(line[1])+1):
        x=list(map(lambda l: ''.join(sorted(l)), combinations(line[0], k)))
        for l in sorted(x):
            print(l)
# 3. itertools.combinations()
def comb1():
    from itertools import combinations
    s , n  = input().split()
    s = sorted(s)
    for i in range(1, int(n)+1):
        for j in combinations(s, i):
            print (''.join(j))
# 4. itertools.combinations_with_replacement()
def combrepl():
    from itertools import combinations_with_replacement
    s, k = input().split()
    print('\n'.join(map(''.join, combinations_with_replacement(sorted(s), int(k)))))
# 5. Compress the String
def stringcompress():
    from itertools import groupby
    data=input()
    for key,items in groupby(data):
        print((tuple(list((len(list(items)),int(key))))),end=' ')
# 5. Compress the String
def stringcompress1():
    from itertools import groupby
    print(*[(len(list(c)), int(k)) for k, c in groupby(input())])
    # 6. Iterables and Iterators
    from itertools import combinations
    n = input()
    s = sorted(''.join(input().split()))
    k = int(input())
    valid, total = 0, 0
    for combination in combinations(s,k):
        total+=1
        if 'a' in combination :
            valid+=1
    print(valid/total)

# %%
#  EXCEPTIONS

# 1. Exceptions 
def exc():
    for i in range(int(input())):
        try:
            a,b=map(int,input().split())
            print(a//b)
        except Exception as e:
            print("Error Code:",e)

# %%
# BUILT INS
# 1. Zip
def zips():
    m,n = map(int,input().split())
    a = []
    for _ in range(n):
        a.append(list(map(float,input().split())))
    [print(sum(x)/n) for x in zip(*a)]

# 2. Python Evaluation
def eva():
    eval(input())

# 3. Sort data:sort the table on the Kth attribute
# 10 2 5
# 7 1 0
# 9 9 9
# 1 23 12
# 6 5 9
def sortonattrib():
    n,m = map(int,input().split())
    a,b = [],[]
    for _ in range(n):
        a.append(list(map(int,input().split())))
    k = int(input())
    [b.append([x[0][k],count]) for count,x in enumerate(zip(a))]
    b.sort(key=lambda x: x[0])
    [print(" ".join(map(str,*x))) for i in b for count,x in enumerate(zip(a)) if count == i[1]]
    # 3. Sort data
    N, M = map(int, input().split())
    rows = [input() for _ in range(N)]
    K = int(input())
    for row in sorted(rows, key=lambda row: int(row.split()[K])):
        print(row)

# 4. ginortS
def checkPr(letter):
    if letter.isalpha():
        if letter.islower():
            return 1
        else:   return 2
    elif int(letter)%2==1:   return 3
    else:   return 4
def alphasort2():
    word = input()
    arr = sorted(word,key= lambda x: (checkPr(x),x) )
    print(*arr,sep='')
# 4. ginortS
def alphasort():
    print(*sorted(input(), key=lambda c: (c.isdigit() - c.islower(), c in '02468', c)), sep='')
# 4. ginortS
def alphasort1():
    order = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1357902468'
    print(*sorted(input(), key=order.index), sep='')

# %%
# Python Functionals

# 1. Map and Lambda Function
fib = lambda y: y if y < 2 else fib(y - 1) + fib(y - 2)
print (list(map(lambda x: x**3, map(fib, range(int(input()))))))

# 2. Validating Email Addresses With a Filter
import re
def fun(s):
    m = re.match(r'[a-zA-Z0-9_-]+@[a-zA-Z0-9]+\.[a-zA-Z]{1,3}$',s)
    return(m)

# %%
# Regex and Parsing

# 1. Introduction to Regex Module
import re
for _ in range(int(input())):
    print (bool(re.match(r'^[-+]?[0-9]*\.[0-9]+$',input())))
# 2. Re.split()
# You are given a string , containing , and/or . and 0-9 digits. 
# Your task is to re.split() all of the , and . symbols.
import re
print(*re.split(r'[.,]+', input().strip('., ')), sep='\n')
# 3. Group(), Groups() & Groupdict()
import re
m = re.search(r'([a-zA-Z0-9])\1+', input().strip())
print(m.group(1) if m else -1)
# 4. Re.findall() & Re.finditer()
# You are given a string . It consists of alphanumeric characters, spaces and symbols(+,-). 
# Your task is to find all the substrings of  that contains  or more vowels. 
# Also, these substrings must lie in between  consonants and should contain vowels only.
import re
v = "aeiou"
c = "qwrtypsdfghjklzxcvbnm"
m = re.findall(r"(?<=[%s])([%s]{2,})[%s]" % (c, v, c), input(), flags = re.I)
print('\n'.join(m or ['-1']))
# 5.Re.start() & Re.end()
# aaadaa
# aa
# (0, 1)  
# (1, 2)
# (4, 5)
import re
s, k = input(), input()
matches = list(re.finditer(r'(?={})'.format(k), s))
if matches:
    print('\n'.join(str((match.start(),
          match.start() + len(k) - 1)) for match in matches))
else:
    print('(-1, -1)')
# 6. Regex Substitution
# You are given a text of  lines. The text contains && and || symbols. 
# Your task is to modify those symbols to the following:
# && → and
# || → or
import re
N = int(input())
for i in range(N):
    print (re.sub(r'(?<= )(&&|\|\|)(?= )', lambda x: 'and' if x.group() == '&&' else 'or', input()))
    
# 7. Validating phone numbers
import re
n = int(input())
for _ in range(n):
    k = re.match(r'(?:[7|8|9])([0-9]{9})(\Z)',str(input()))
    try:
        if(k.group(0)):
            print("YES")
    except:
        print("NO")
# 7. Validating phone numbers
if re.match(r'[789]\d{9}$',raw_input()):   
    print 'YES'  
else:  
    print 'NO'  
    
# 8. Validating and Parsing Email Addresses
# A valid email address meets the following criteria:
# It's composed of a username, domain name, and extension assembled in this format: username@domain.extension
# The username starts with an English alphabetical character, and any subsequent characters consist of one or more 
# of the following: alphanumeric characters, -,., and _.
# The domain and extension contain only English alphabetical characters.
# The extension is , , or  characters in length.
import re
n = int(input())
for _ in range(n):
    x, y = input().split(' ')
    m = re.match(r'<[A-Za-z](\w|-|\.|_)+@[A-Za-z]+\.[A-Za-z]{1,3}>', y)
    if m:
        print(x,y)
# 8. Validating and Parsing Email Addresses
import re
import email.utils
n = int(input().strip())
temp =[]
a = re.compile(r'<[a-z0-9][\w._-]+@[a-z]+\.[a-z]{1,3}>', re.I)
for _ in range(n):
    temp.append(input().strip())
for i, x in enumerate(temp):
    v =  a.search(x)
    if v:
        print(temp[i])
        
# 9. Validating UID
def check(S):
    if len(S) == 10 and len(set(S)) == 10 and S.isalnum() and sum([1 for i in S if i.isupper()]) >= 2 and sum([1 for i in S if i.isdigit()]) >= 3:
        return "Valid"
    else:
        return "Invalid"
n = int(input())
[print(check(input())) for i in range(n)]
# 9. Validating UID
import re
for _ in range(int(input())):
    s = input()
    print('Valid' if all([re.search(r, s) for r in [r'^[A-Za-z0-9]{10}$',r'([A-Z].*){2}',r'([0-9].*){3}']]) and not re.search(r'.*(.).*\1', s) else 'Invalid')

# 10. Validating Credit Card Numbers
n = int(input())
for _ in range(n):
    S = input()
    try:
        assert re.search(r'^[456]',S)
        assert re.search(r'^(\d{4}-){3}\d{4}$',S) or re.search(r'\d{16}$',S)
        assert not re.search(r' _',S)
        assert not re.search(r"([\d])\1\1\1", S.replace("-", ""))
    except:
        print('Invalid')
    else:
        print('Valid')
n = int(input())
     
# 11. Validating Postal Codes
import re
s=input()
print (bool(re.match(r'^[1-9][\d]{5}$',s) and len(re.findall(r'(\d)(?=\d\1)',s))<2 ))

# %%
# HTML Parser
from html.parser import HTMLParser
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):        
        print ('Start :',tag)
        for ele in attrs:
            print ('->',ele[0],'>',ele[1])
            
    def handle_endtag(self, tag):
        print ('End   :',tag)
        
    def handle_startendtag(self, tag, attrs):
        print ('Empty :',tag)
        for ele in attrs:
            print ('->',ele[0],'>',ele[1])
            
MyParser = MyHTMLParser()
MyParser.feed(''.join([input().strip() for _ in range(int(input()))]))

# %%
# Regex Self Study
# 1. Search for a pattern in the string
import re
st = 'how are ! how are you doing, This is the series: 1, 123,34.23, 338*'
match = re.search(r'H\w+', st, re.I)
print(match.group())
# 2. Search for all occurances of the word in the string. 
st = 'Hello, how are ! what are you doing, This is the series: 1, 123,34.23, 338*'
match = re.findall(r'(?<![a-z0-9])h\w+', st, re.I)
print(match)
# 3. Search for the word starting with a specific letter and should be preceded by a space in the string
st = ' Hello, how are ! what are you doing, This is the series: 1, 123,34.23, 338*'
match = re.findall(r'(?<= )h\w+', st, re.I)
print(match)
# 4. Search for the word starting with a specific letter and should be preceded by a space in the string
st = ' Hello, how are ! what are you doing, This is the series: 1, 123,34.23, 338*'
match = re.findall(r'(?:^|\b)([0-9]+)(?:\b)', st, re.I)
g = '\n'
print("\n".join(match))
# 5. Replace string 
st = 'Hello,How are ! what are you doing, This is the series: 1, 123,34.23, 338*'
print(st.replace("Hello", "watsaup"))
#replaces words starting with H preceded by space
print(re.sub(r'(?: )[H]', " h", st, re.I))

# 6. replaces words starting with H preceded by space
st = 'Hello,How are ! what are you doing, This is the series: 1, 123,34.23, 338*. And thats How its done'
print(re.sub(r'(?:\b)[H]', "h", st))

# 7. Email Address
st = 'Hello,How are ! what are you doing. This is my email address: harshil2808@23gmail.com'
m = re.search(r'(?:\b)([^\s]*\@[^\s]*\.[a-zA-Z]{2,4})(?:\b)',st)
print(m.group(0))

# 8. Email Address
def email():
    testString = "This is a string with an email@address.com embedded in it."
    matchObj = re.search(r"(?:\b)([^\s]*\@[^\s]*\.[a-zA-Z]{2,4})(?:\b)",testString)
    print (matchObj.group(1))
    
# 9. Print the domain name of the website
testString = "http://www.thehindu.com/features/education/issues/engineering-students-locked-into-microsoft-office/article4640546.ece"
matchObj = re.search(r"(?://)([\w.]*)",testString)
print (matchObj.group(1))

# 10. Remove duplicate characters and print only one occurence
re.sub(r'([a-z])\1+', r'\1', 'ffffffbbbbbbbqqq')
'fbq'

# 11. Emails
def email1():
    import email.utils
    print (email.utils.parseaddr('DOSHI <DOSHI@hackerrank.com>'))
    print (email.utils.formataddr(('DOSHI', 'DOSHI@hackerrank.com')))

# input - DOSHI <DOSHI@hackerrank.com>
def email2():
    n = int(input())
    for _ in range(n):
        x, y = input().split(' ')
        m = re.match(r'<[A-Za-z](\w|-|\.|_)+@[A-Za-z]+\.[A-Za-z]{1,3}>', y)
        if m:
            print(x,y)
def email3():
    R = r'<[a-zA-Z][\d\w\.-]*@[a-zA-Z]+\.[a-zA-Z]{1,3}>'
    for _ in range(int(input().strip())):
        i = input()
        a = re.search(R, i)
        if a:
            print(i)
def email4():
    t = '<lkajsdl1234fj@as.com>'
    m = re.search(r'<[\w]*@[a-zA-Z]{1,3}\.[\D]{1,3}>', t)
    print(m.group(0))

def email5():
    [print(e.strip('\n')) for e in sys.stdin if re.search('<[a-z][a-z0-9_.-]+@[a-z]+\.[a-z]{1,3}>', e, re.I)]

def ch(s):
    try:
        m = re.match(r'[a-zA-Z0-9_-]*@[a-zA-Z]*.[a-zA-Z]{1,3}$', s)
#         m = re.match(r'[\w-]*@[\D]*.[\D]{1,3}$', s) Can also be written 
        print(m.group(0))
    except:
        print('Error')
ch("brian23@hackerrank.com")

# %%
# Strings Self Study

# 1. to print the list without square brackets
def strings1():
    n = int(input())
    [', '.join(email.utils.parseaddr(input())) for _ in range(n)]

# %%
#  Lambda map Reduce Self Study 

# 1. LAMBDA MAP FILTER
def fibo():
    fib = lambda y : y if (y<2) else fib(y-1) + fib(y-2)
    print(list(map(lambda x: x**2, map(fib,range(int(input()))))))

def fibo1():
    h = lambda y : y if (y<2) else fib(y-1) + fib(y-2)
    print(list(map(lambda x : x **2 , map(fib, range(int(input()))))))

# 2. Lambda 
fib = lambda y: y if y < 2 else fib(y - 1) + fib(y - 2)
print (list(map(lambda x: x**3, map(fib, range(int(input()))))))

# 3. Lamda 
cube = lambda x: pow(x,3)# complete the lambda function 
def fibonacci(n):
     # return a list of fibonacci numbers
    lis = [0,1]
    for i in range(2,n):
        lis.append(lis[i-2] + lis[i-1])
    return(lis[0:n])
print(cube)

# 3. lambda 
def lamb():
    lm = list(range(0,10,2))
    ls = list(map(lambda x : x*2,lm))
    print(ls)

# %%
import re

# %%
# http://www.w3resource.com/python-exercises/re/#EDITOR
# 1.
string = 'asdl ljartjoj caljsasdf312423 er jh lsjlgwer l oquwe8954  lajsdf8349 '
# Write a Python program to check that a string contains only a certain set of characters (in this case a-z, A-Z and 0-9)
def assignment(string):
    try:
        pattern = r'^[\w .]*'
        m = re.search(pattern, string)
        print(m.group(0))
    except:
        print('Error')
assignment(string)

# %%
# 2. 
string = 'Harry Potter'
# # Write a Python program that matches a string that has an 
# # a followed by zero or more b's
# patterns = r'ab*'
# # a followed by one or more b's
# patterns = r'ab+'
# # a followed by zero or one 'b'
# patterns = r'ab?'
# # a followed by zero or one 'b'
# patterns = r'ab{3}'
# # a followed by zero or one 'b'
# patterns = r'ab{2,3}'
# # sequences of lowercase letters joined with a underscore
# patterns = r'^[a-z]+_[a-z]+$'
# # 8. sequences of one upper case letter followed by lower case letters
# patterns = r'^[A-Z][a-z]+'
# # 9. matches a string that has an 'a' followed by anything, ending in 'b'
# patterns = r'a.*?b' #string = 'Gojbasdl abljartjojb caljsabbbb'
# # 10. matches a word at the beginning of a string
# patterns = r'^\w+' #string = ''Harry Potter'
# # 10. matches a word at the beginning of a string
# patterns = r'^\w+' #string = ''Harry Potter'

def assignment(string):
    try:
        m = re.findall(patterns, string)
        print(m)
    except:
        print('Error')
assignment(string)

# %%
# 2. 
# # 11. matches a word at end of string, with optional punctuation
# patterns = r'\w+\S*$' #string = 'Harry Potter.@#' Nstring = 'Harry Potter'
# # 12. matches a word containing 'z'.
# patterns = r'\w*z.\w*' #string = 'Hazrry Potter' Nstring = 'Harry Potter z'
# # 13. matches a word containing 'z', not start or end of the word
# patterns = r'\Bz\B' #string = 'Hazrry Potter az' Nstring = 'Harry Potter z'
# # 14. match a string that contains only upper and lowercase letters, numbers, and underscores.
# patterns = r'^\w+$' #string = 'Hazrry Potter az' Nstring = 'Harry Potter z'
# # 15. string will start with a specific number
# patterns = r'^\d.*$' #string = '2HarryPotterz' Nstring = '@2HarryPotterz 2asdf'
# # 16. remove leading zeros from an IP address
# patterns = '\.[0]*' #subs("216.08.01.196")
# # 17. check for a number at the end of a string
# patterns = '.*\d$' #assignment("asd21346")
# # 18. search the numbers (0-9) of length between 1 to 3 in a given string
# patterns = '[0-9]{1,3}' #finds("asd21346")
# # 19. search some literals strings in a string
# patterns = "fox" #searching("The quick brown fox jumps over the lazy dog.")
# # 20. search a literals string in a string and also find the location within the original string where the pattern occurs
# patterns = "fox" #searching("The quick brown fox jumps over the lazy dog.")
# s = m.start()
# e = m.end()
# # 21. program to find the substrings within a string
# patterns = "fox" #searching("The quick brown fox jumps over the lazy dog.")
# for match in re.findall(pattern, text):
#     print('Found "%s"' % match)
# # 22. search some literals strings in a string
# patterns = "exercises" #searching("Python exercises, PHP exercises, C# exercises")
# for match in re.finditer(pattern, text):
#     s = match.start()
#     e = match.end()
#     print('Found "%s" at %d:%d' % (text[s:e], s, e))

def assignment(string):
    try:
        m = re.match(patterns, string)
        print(m.group(0))
    except:
        print('Error')
def searching(string):
    try:
        m = re.search(patterns, string)
        print(m.group(0))
    except:
        print('Error')
        
def subs(string):
    try:
        m = re.sub(patterns, '.', string)
        print(m)
    except:
        print('Error')
def finds(string):
    try:
        m = re.findall(patterns, string)
        print(m)
    except:
        print('Error')
# assignment("12TESAdasda asd21346")
# finds("23")
# searching("The quick brown fox jumps over the lazy dog.")
# subs("216.08.01.196")

# %%
# 23. replace whitespaces with an underscore and vice versa
patterns = "_" #searching("The quick brown fox jumps over the lazy dog.")
def rep(string):
    try:
        m = re.sub(patterns,' ', string)
        print(m)
    except:
        print('Error')
# rep("Hello World")

# 24. extract year, month and date from a an url
patterns = r'/(/d{4}/(/d{2}/(/d{2}))' #searching("The quick brown fox jumps over the lazy dog.")
def ext(string):
    try:
        m = re.findall(r'/(\d{4})/(\d{1,2})/(\d{1,2})/' , string)
        [print(i) for i in m]
    except:
        print('Error')
# ext("https://www.washingtonpost.com/news/football-insider/wp/2016/09/02/odell-beckhams-fame-rests-on-one-stupid-little-ball-josh-norman-tells-author/")

# 25. convert a date of yyyy-mm-dd format to dd-mm-yyyy format
def repdate(string):
    try:
        return re.sub(r'(\d{4})-(\d{1,2})-(\d{1,2})', '\\3-\\2-\\1', string)
    except:
        print('Error')
# repdate("2026-01-02")

# 27. separate and print the numbers of a given string
def resplit(string):
    try:
        m = re.split(r'\D+', string)
        [print(i) for i in m]
    except:
        print('Error')
# resplit("Ten 10, Twenty 20, Thirty 30")

# 28. find all words starting with 'a' or 'e'
def findwords(string):
    try:
        m = re.findall('[ae]\w+', string)
        print(m)
    except:
        print('Error')
findwords("The following example creates an ArrayList with a capacity of 50 elements. Four elements are then added to the ArrayList and the ArrayList is trimmed accordingly.")

# %%
# 29. separate and print the numbers and their position of a given string
def findwords(string):
    try:
        m = re.finditer('\d+', string)
        [print(i.group(0))for i in m]
    except:
        print('Error')
# 32. Replace maximum 2 occurrences of space, comma, or dot with a colon
def subabbr(string):
    try:
        m = re.sub(r'[;. ]',':', string,2)
        print(m)
    except:
        print('Error')
# subabbr("This Road goes to Amsterdam:")
# 34. program to find all three, four, five characters long word in a string
def subword(string):
    try:
        m = re.findall(r'\b\w{3,5}\b',string)
        print(m)
    except:
        print('Error')
# subword("There Roads goes to Amsterdam:")
# 35. find all words which are at least 4 characters long
def subword(string):
    try:
        m = re.findall(r'\b\w{4,}\b',string)
        print(m)
    except:
        print('Error')
# subword("There Roads goes to Amsterdam:")

# 36. Convert camel case string to snake case string
def camel_to_snake(text):
    str1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', text)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', str1).lower()
# camel_to_snake("There Roads goes to Amsterdam:")

# 37. convert snake case string to camel
def snake_to_camel(text):
    return ''.join(x.capitalize() for x in text.split('_'))
# snake_to_camel("there_roads_goes_to_amsterdam:")

# 38. extract values between quotation marks of a string
def quotes(text):
    try:
        m = re.findall(r'"(.*?)"',text)
        print(m)
    except:
        print('Error')
quotes('There Roads "goes to" Amsterdam')

# %%
# 39. remove multiple spaces in a string
def removemulti(text):
    try:
        m = re.sub(r' [ ]*',' ',text)
        print(m)
    except:
        print('Error')
# removemulti("how   are you .  This is   the  first of times  ")
# 40.program to remove all whitespaces from a string
def removeall(text):
    try:
        m = re.sub(r' ','',text)
        print(m)
    except:
        print('Error')
# removeall("how   are you .  This is   the  first of times  ")
# 41. remove everything except alphanumeric characters from a string
def removenonalhpa(text):
    try:
        m = re.sub(r'\W+','',text)
        print(m)
    except:
        print('Error')
# removenonalhpa("how   are you .  This is   the  first of times  ")
# 42. find urls in a string
def findurls(text):
    try:
        m = re.search(r'http[s]*://www.[a-zA-Z0-9_]*.com',text)
        print(m.group(0))
    except:
        print('Error')
# findurls("how are you .This is the url : http://www.google.com")
# 43. split a string at uppercase letters      
def splitatUpper(text):
    try:
        m = re.split(r'[A-Z]',text)
        print(m)
    except:
        print('Error')
# splitatUpper("How are you .This is the Url : http://www.Google.com")
# 44. do a case-insensitive string replacement
def replacesIgnoreCase(text):
    try:
        redata = re.compile(re.escape('php'), re.IGNORECASE)
        m = redata.sub('Python',text)
        print(m)
    except:
        print('Error')
# replacesIgnoreCase("How are you .This is the PHP Url : http://www.Google.com")
# 45. remove the ANSI escape sequences
def removeANSI(text):
    try:
        reaesc = re.compile(r'\x1b[^m]*m')
        m = reaesc.sub('', text)
        print(m)
    except:
        print('Error')
# removeANSI("\t\u001b[0;35mgoogle.com\u001b[0m \u001b[0;36m216.58.218.206\u001b[0m")
# 46. remove the ANSI escape sequences
def findAdverb(text):
    try:
        for m in re.finditer(r"\w+ly", text):
            print('%d-%d: %s' % (m.start(), m.end(), m.group(0)))
    except:
        print('Error')
# findAdverb("Clearly, he has no excuse for such behavior.")
# 47. split a string with multiple delimiters
def splitmulti(text):
    try:
        m = re.split(r",| ", text)
        print(m)
    except:
        print('Error')
# splitmulti("Clearly,he has no excuse for such behavior.")
# 48. check a decimal with a precision of 2
def searchdec(text):
    try:
        m = re.search(r"\d+\.[0-9]{1,2}$", text)
        print(m.group(0))
    except:
        print('Error')
# searchdec("654.10")
# 49. remove words from a string of length between 1 and a given number
def removewords(text):
    try:
        m = re.sub(r"\W*\b\w{1,3}\b",'', text)
        print(m)
    except:
        print('Error')
# removewords("Clearly,he has no excuse for such behavior.")
# 50. remove the parenthesis area in a string
def removeparan(text):
    try:
        [print(re.sub(r"\(.*\)",'', i)) for i in text]
    except:
        print('Error')
removeparan(["example (.com)", "w3resource", "github (.com)", "stackoverflow (.com)"])
